# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from Results_Handler import ResultsHandler

# %%
# %matplotlib widget

# %%
df = pd.read_csv('/Users/mvalatsou/PhD/Repos/MR_perplex/OUTPUT/combined.csv')
print(df['planet_type'].unique())

ResultsHandler.water_loss(df)
# ResultsHandler.metallicity_change(df)
# Out:
# ['sub-Neptunes (10% H2O)']
# /Users/mvalatsou/PhD/Repos/Mass-Loss/Results_Handler.py:544: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = (df['planet_type'].str.contains('sub-Neptunes') & df['planet_type'].str.contains(r'(10% H2O|20% H2O)'))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# df['Phi_H_atoms'] = df['phi_H'] / 1
# df['Phi_O_atoms'] = df['phi_O'] / 16
# df['N_H_s'] = df['Phi_H_atoms'] * 4 * np.pi * df['REUV']**2
# df['N_O_s'] = df['Phi_O_atoms'] * 4 * np.pi * df['REUV']**2
# df['ratio_OH_atoms'] = df['N_O_s'] / df['N_H_s']

# plt.figure(figsize=(5,4))


# plt.hist(df['ratio_OH_atoms'].dropna(), bins=np.logspace(-4,1,30), log=True)
# plt.xscale('log')

# plt.xlabel('ratio')
# plt.ylabel('Count')
# plt.title('Distribution of O/H Flux Ratio')
# plt.tight_layout()
# plt.show()
